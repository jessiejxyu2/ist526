# %% [markdown]
# <a href="https://colab.research.google.com/github/jessiejxyu2/ist526/blob/main/Hello_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IST 526 Pre-class Activity

# %%
import pandas as pd
# loading country data from github
df_country = pd.read_csv("https://raw.githubusercontent.com/smbillah/ist526/main/gapminder.csv")
display(df_country.head())
display(df_country.tail())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# ...

# %% [markdown]
# - Do you see a list of countries with some statistics? \
#   **Yes.**
# - What does the above code snippet do?\
#   **The code load the data and diplay a chart with different contries' data.**
# - Where did it get the country data?\
#   **From the link "https://raw.githubusercontent.com/smbillah/ist526/main/gapminder.csv".**
